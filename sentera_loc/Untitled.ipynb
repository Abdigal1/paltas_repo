# %%
import pandas as pd

# %%
a = pd.read_excel("selecciones_automaticas.xlsx", header=0)
a.head(5)
# Out:
#   Unnamed: 0 17_vuelo_agosto-13 (SENTERA V1) 17_vuelo_agosto-13 (SENTERA V2)  \
# 0   Basename              Selected_basenames              Selected_basenames
# 1    A01.jpg               ['IMG_00062.jpg']               ['IMG_00060.jpg']
# 2    A02.jpg               ['IMG_00066.jpg']               ['IMG_00066.jpg']
# 3    A03.jpg               ['IMG_00069.jpg']               ['IMG_00069.jpg']
# 4    A04.jpg               ['IMG_00073.jpg']               ['IMG_00072.jpg']
#
#   18_vuelo_agosto-19 (SENTERA V1) 19_vuelo_setiembre-15 (SENTERA V1)   \
# 0              Selected_basenames                  Selected_basenames
# 1               ['IMG_00046.jpg']                   ['IMG_00088.jpg']
# 2               ['IMG_00050.jpg']                   ['IMG_00091.jpg']
# 3               ['IMG_00052.jpg']                   ['IMG_00094.jpg']
# 4               ['IMG_00057.jpg']                   ['IMG_00098.jpg']
#
#   20_vuelo_setiembre-24 (SENTERA V1)
# 0                  Selected_basenames
# ...

# %%
a = pd.read_excel("selecciones_automaticas.xlsx", header=1)
a.head(20)
# Out:
#    Basename Selected_basenames Selected_basenames.1 Selected_basenames.2  \
# 0   A01.jpg  ['IMG_00062.jpg']    ['IMG_00060.jpg']    ['IMG_00046.jpg']
# 1   A02.jpg  ['IMG_00066.jpg']    ['IMG_00066.jpg']    ['IMG_00050.jpg']
# 2   A03.jpg  ['IMG_00069.jpg']    ['IMG_00069.jpg']    ['IMG_00052.jpg']
# 3   A04.jpg  ['IMG_00073.jpg']    ['IMG_00072.jpg']    ['IMG_00057.jpg']
# 4   A05.jpg  ['IMG_00077.jpg']    ['IMG_00076.jpg']    ['IMG_00060.jpg']
# 5   A06.jpg  ['IMG_00080.jpg']    ['IMG_00079.jpg']    ['IMG_00063.jpg']
# 6   A07.jpg  ['IMG_00084.jpg']    ['IMG_00083.jpg']    ['IMG_00067.jpg']
# 7   A08.jpg  ['IMG_00088.jpg']    ['IMG_00087.jpg']    ['IMG_00071.jpg']
# 8   A09.jpg  ['IMG_00091.jpg']    ['IMG_00090.jpg']    ['IMG_00074.jpg']
# 9   A10.jpg  ['IMG_00100.jpg']    ['IMG_00099.jpg']    ['IMG_00083.jpg']
# 10  A11.jpg  ['IMG_00103.jpg']    ['IMG_00103.jpg']    ['IMG_00087.jpg']
# 11  A12.jpg                NaN                  NaN                  NaN
# ...
